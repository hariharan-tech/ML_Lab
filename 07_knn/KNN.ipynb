# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import KNN

# %%
df = pd.read_csv("knn_dataset.csv")

# %%
colors = ["k","g","b"]

# %%
for i in range(len(df["X1"])):
    plt.scatter(df["X1"][i],df["X2"][i],c=colors[df["cluster"][i]])

# %%
knn = KNN.KNN(df,11,"Euclidean")

# %%
point1 = KNN.Point2D(3,4.9)
point2 = KNN.Point2D(3.5,3)

# %%
knn.get_dist(point1,point2)
# Out:
# 1.9646884202957153

# %%
pt_val1 = knn.knn_cluster(point1)
pt_val2 = knn.knn_cluster(point2)
pt_val1, pt_val2
# Out:
# {0: 0, 1: 5, 2: 6}
# {0: 2, 1: 9, 2: 0}
# (2, 1)

# %%
df["species"].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
for i in range(len(df["X1"])):
    plt.scatter(df["X1"][i],df["X2"][i],c=colors[df["cluster"][i]])
plt.scatter(point1.x,point1.y,c=colors[pt_val1],marker="*",edgecolors="k",s=100)
plt.scatter(point2.x,point2.y,c=colors[pt_val2],marker="*",edgecolors="k",s=100)
